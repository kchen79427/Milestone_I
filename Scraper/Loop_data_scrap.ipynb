# %%
import tabula
import pandas as pd
from tabula import read_pdf
HEADERS=['Car','Driver','AvgStart','AvgMidRace','AvgFinish','Avg Pos','LapsLed','PercentLapsLed','TotalLaps','DriverRating','Pts','PassDiff','GreenPass','GreenPassed','QualityPasses','PercentQualityPasses','NumFastestLaps','LapsinTop15','PercentLapsTop15']
data_location=r"C:\Users\kchen\OneDrive\MADS\SIADS591_592_Milestone1\Data\loop\01 - 2022_Daytona_500_results.pdf"
df=read_pdf(r"C:\Users\kchen\OneDrive\MADS\SIADS591_592_Milestone1\Data\loop\01 - 2022_Daytona_500_results.pdf",pages='1')

# %%
df[0].head(10)
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN              NaN        NaN        NaN        NaN        NaN
# 1        NaN              NaN        NaN        NaN        NaN        NaN
# 2        NaN              NaN        NaN        NaN        NaN        NaN
# 3        Car           Driver        Avg    Avg Mid        Avg    Avg Pos
# 4        NaN              NaN      Start       Race     Finish        NaN
# 5          2   Austin Cindric        5.0        2.0        1.0        6.2
# 6          6  Brad Keselowski        3.0        5.0        9.0        4.8
# 7         19  Martin Truex Jr       14.0       18.0       13.0       11.9
# 8         23    Bubba Wallace       16.0       19.0        2.0       10.2
# 9         14    Chase Briscoe        9.0       10.0        3.0       18.3
#
#                                            Box Score         Unnamed: 6  \
# 0                     Daytona International Speedway                NaN
# 1                                        DAYTONA 500                NaN
# 2  Provided by NASCAR Statistics at 2/20/2022 11:...                NaN
# 3       Pass Green Green Quality % Quality # Fastest  Laps in % Laps in
# 4                Diff Pass Passed Passes Passes Laps      Top 15 Top 15
# 5                             -13 168 181 125 74.4 0           176 87.6
# 6                               1 171 170 148 86.5 4           198 98.5
# 7                              25 258 233 192 74.4 4           143 71.1
# 8                              16 253 237 191 75.5 7           145 72.1
# 9                               17 209 192 70 33.5 6            88 43.8
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN         NaN         NaN
# 3   Laps Led     % Laps      Total      Driver         Pts
# 4        NaN        Led       Laps      Rating         NaN
# 5         21       10.4        201       122.4          54
# 6         67       33.3        201       121.3          54
# 7         11        5.5        201        94.0          49
# 8         12        6.0        201       104.7          47
# 9          0        0.0        201        75.0          41

# %%
df2=df[0].iloc[5:]
df2['Box Score']=df2['Box Score'].str.split()
df2['Unnamed: 6']=df2['Unnamed: 6'].str.split()
# Out:
# <ipython-input-40-7bdd3a267513>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Box Score']=df2['Box Score'].str.split()
# <ipython-input-40-7bdd3a267513>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Unnamed: 6']=df2['Unnamed: 6'].str.split()

# %%
df3=pd.DataFrame(df2['Box Score'].tolist(), columns=['PassDiff','GreenPass','GreenPassed','QualityPasses','PercentQualityPasses','NumFastestLaps'])
df4=pd.DataFrame(df2['Unnamed: 6'].tolist(), columns=['LapsinTop15','PercentLapsTop15'])

# %%
df2=df2[['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 8',
       'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']]
# Out:
# (40, 11)

# %%
df2=df2.reset_index(drop=True)
df_final=pd.concat([df2,df3,df4],axis=1)
df_final.columns=HEADERS
# Out:
# (40, 2)

# %%
df_final.head()
# Out:
#   Car           Driver AvgStart AvgMidRace AvgFinish Avg Pos LapsLed  \
# 0   2   Austin Cindric      5.0        2.0       1.0     6.2      21
# 1   6  Brad Keselowski      3.0        5.0       9.0     4.8      67
# 2  19  Martin Truex Jr     14.0       18.0      13.0    11.9      11
# 3  23    Bubba Wallace     16.0       19.0       2.0    10.2      12
# 4  14    Chase Briscoe      9.0       10.0       3.0    18.3       0
#
#   PercentLapsLed TotalLaps DriverRating Pts PassDiff GreenPass GreenPassed  \
# 0           10.4       201        122.4  54      -13       168         181
# 1           33.3       201        121.3  54        1       171         170
# 2            5.5       201         94.0  49       25       258         233
# 3            6.0       201        104.7  47       16       253         237
# 4            0.0       201         75.0  41       17       209         192
#
#   QualityPasses PercentQualityPasses NumFastestLaps LapsinTop15  \
# 0           125                 74.4              0         176
# 1           148                 86.5              4         198
# 2           192                 74.4              4         143
# 3           191                 75.5              7         145
# 4            70                 33.5              6          88
#
#   PercentLapsTop15
# 0             87.6
# 1             98.5
# 2             71.1
# 3             72.1
# 4             43.8

# %%
df_final.shape
# Out:
# (40, 19)
